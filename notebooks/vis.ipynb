# %%
import math
from typing import List, Union
from transformers import PreTrainedTokenizerBase


def single_loss_diff_to_color(loss_diff: float) -> str:
    def sigmoid(x: float) -> float:
        return 1 / (1 + math.exp(-x))

    scaled_loss_diff = sigmoid(loss_diff)  # scale to 0-1

    if scaled_loss_diff < 0.5:  # red
        red_val = 255
        green_blue_val = min(int(255 * 2 * scaled_loss_diff), 255)
        return f"rgb({red_val}, {green_blue_val}, {green_blue_val})"
    else:  # green
        green_val = 255
        red_blue_val = min(int(255 * 2 * (1 - scaled_loss_diff)), 255)
        return f"rgb({red_blue_val}, {green_val}, {red_blue_val})"


def visualize_tokens_html(
    token_ids: List[int],
    tokenizer: PreTrainedTokenizerBase,
    token_values: List[Union[float, int]],
) -> str:
    if len(token_ids) != len(token_values):
        raise ValueError(
            "The number of token IDs must match the number of token values."
        )

    token_htmls = []
    for token_id, value in zip(token_ids, token_values):
        str_token = tokenizer.decode(token_id).replace(" ", "&nbsp;")
        str_token = str_token.replace("<", "&lt;").replace(">", "&gt;")

        bg_color = single_loss_diff_to_color(float(value))

        token_html = f"""
        <div style="display: inline-block; border: 1px solid #888; font-family: monospace; 
                    font-size: 14px; color: black; background-color: {bg_color}; 
                    margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;" 
             title="Value: {value:.2f}">
            {str_token}
        </div>
        """
        token_htmls.append(token_html)

        if str_token == "&nbsp;\n":
            token_htmls.append("<br>")

    html_output = f"""
    <div style="line-height: 1.5;">
        {''.join(token_htmls)}
    </div>
    """

    return html_output

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from IPython.display import HTML

model = AutoModelForCausalLM.from_pretrained("google/gemma-2-2b")
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b")

display(HTML(visualize_tokens_html([1, 2, 3], tokenizer, [0.1, 0.2, 0.3])))
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(242, 255, 242);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 0.10">
#             &lt;eos&gt;
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(229, 255, 229);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 0.20">
#             &lt;bos&gt;
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(217, 255, 217);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 0.30">
#             &lt;unk&gt;
#         </div>
#
#     </div>

# %%
import torch

diff = torch.load("../results/diff_direction_google--gemma-2-2b_snarks_S0_N151.pt")
diff.shape
# Out:
# /tmp/ipykernel_4323/30182805.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   diff = torch.load("../results/diff_direction_google--gemma-2-2b_snarks_S0_N151.pt")
# torch.Size([26, 2304])

# %%
import pickle

with open("../results/eval_google--gemma-2-2b_snarks_S0_N151.pkl", "rb") as f:
    eval_results = pickle.load(f)

eval_results.questions[0]
# Out:
# EvalQuestion(tokens=[2, 99211, 948, 576, 1378, 26099, 603, 108135, 235265, 110, 235368, 235292, 12236, 6218, 603, 108135, 235336, 109, 1261, 16358, 235292, 108, 235278, 235280, 235275, 1315, 235303, 235256, 476, 16744, 1552, 235269, 5326, 577, 14650, 476, 24981, 6249, 674, 919, 9244, 15011, 577, 1707, 5982, 575, 1476, 235265, 108, 235278, 235305, 235275, 1315, 235303, 235256, 476, 27562, 1552, 235269, 5326, 577, 14650, 476, 24981, 6249, 674, 919, 9244, 15011, 577, 1707, 5982, 575, 1476, 235265, 235248, 109, 5958,
 235305, 235275, 6372, 16031, 574, 1105, 1855, 42831, 235269, 674, 235303, 235256, 1212, 15667, 665, 21801, 235265, 109, 5958, 33720, 889, 1368, 692, 708, 7166, 1105, 573, 3210, 235269, 1492, 2734, 861, 3448, 575, 573, 5920, 664, 651, 1963, 3448, 603, 235292, 591, 235356, 97294, 1165, 235303, 235256, 1508, 2845, 674, 692, 9288, 577, 736, 5920, 235265, 109, 5331, 235303, 235256, 1742, 4065, 731, 4065, 235292, 108, 2495, 783, 1612, 696, 591, 235280, 823, 665, 15904, 674, 10241, 689, 20021, 22419, 1105, 45776, 603, 12763, 578, 22012, 235265, 4560, 235269, 45776, 603, 5604, 577, 614, 671, 63488, 578, 32520, 8409, 728, 712, 573, 8566, 576, 1582, 476, 200135, 575, 591, 235280, 235275, 15904, 674, 665, 7744, 476, 10122, 576, 65971, 578, 105004, 235265, 108, 2495, 783, 1612, 696, 591, 235305, 823, 665, 21721, 674, 10241, 689, 20021, 22419, 1105, 45776, 603, 21801, 578, 52552, 235265, 1417, 603, 72002, 476, 17120, 578, 5112, 6218, 235265 ...

# %%
from cot_probing.activations import clean_run_with_cache_sigle_batch
# Out:
# torch.Size([26, 3281, 2304])

# %%
correct = 0
incorrect = 0
for q in eval_results.questions:
    if q.is_correct:
        correct += 1
    else:
        incorrect += 1
print(f"Correct: {correct}, Incorrect: {incorrect}")
# Out:
# Correct: 7, Incorrect: 66

# %%
def vis_q(q_idx: int, layers):
    acts = clean_run_with_cache_sigle_batch(
        model,
        torch.tensor([eval_results.questions[q_idx].tokens]),
        list(range(model.config.num_hidden_layers)),
        list(range(len(eval_results.questions[q_idx].tokens))),
    ).cpu()
    probe_acts = einsum(
        "layers locs d_model, layers d_model -> layers locs", acts, diff.cpu()
    )
    for _layer_idx, layer in enumerate(layers):
        print(f"Layer {layer}")
        first_response_loc = eval_results.questions[q_idx].locs["response"][0] - 10 - 80
        display(
            HTML(
                visualize_tokens_html(
                    eval_results.questions[q_idx].tokens[first_response_loc:],
                    tokenizer,
                    probe_acts[layer, first_response_loc:].tolist(),
                )
            )
        )

# %%
vis_q(0)
# Out:
# torch.Size([26, 3281, 2304])
# Layer 5
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.19">
#             &nbsp;answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 49.28">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.54">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 52.02">
#             &nbsp;(
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 50.97">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.60">
#             ).
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 21.76">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 25.01">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.20">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 26.85">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 13.76">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.78">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.44">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.11">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 34.06">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.83">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 29.14">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 49.67">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.74">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 33.06">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.62">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.70">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.00">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.07">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monosp
# Layer 10
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 78.93">
#             &nbsp;answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 93.19">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 105.13">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 98.59">
#             &nbsp;(
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 95.95">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 86.88">
#             ).
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 93.12">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 91.76">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 77.57">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 114.12">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 97.18">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 125.20">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 115.56">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 105.49">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 89.24">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 100.33">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 107.86">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 145.40">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value:
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 230.20">
#             &nbsp;reality
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 180.97">
#             &nbsp;where
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 216.06">
#             &nbsp;software
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 92.91">
#             &nbsp;often
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 137.09">
#             &nbsp;malfunctions
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 269.83">
#             .
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 366.81">
#
#
#         </div>
# Layer 20
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 707.39">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 770.18">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 723.70">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 799.82">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 823.42">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 728.99">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 690.82">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 864.90">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 795.86">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 729.04">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 544.97">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 495.91">
#             &nbsp;But
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 305.72">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 389.01">
#             &nbsp;could
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 534.07">
#             &nbsp;never
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 522.25">
#             &nbsp;happen
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 668.71">
#             &nbsp;in
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 625.81">
#             &nbsp;reality
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 689.71">
#             &nbsp;where
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 583.31">
#             &nbsp;software
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 510.14">
#             &nbsp;often
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 442.70">
#             &nbsp;malfunctions
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 660.59">
#             .
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1005.19">
#
#
#         </div>
# Layer 25
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -227.89">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -46.41">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 109.32">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 526.45">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -163.24">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.30">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 67.34">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 437.16">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 391.80">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 71.10">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -529.48">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -428.50">
#             &nbsp;But
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -495.51">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -357.95">
#             &nbsp;could
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -405.85">
#             &nbsp;never
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -443.66">
#             &nbsp;happen
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -607.31">
#             &nbsp;in
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -449.98">
#             &nbsp;reality
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -463.10">
#             &nbsp;where
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -248.86">
#             &nbsp;software
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -308.63">
#             &nbsp;often
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -400.58">
#             &nbsp;malfunctions
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -458.08">
#             .
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 416.39">
#
#
#         </

# %%
vis_q(2)
# Out:
# torch.Size([26, 3315, 2304])
# Layer 5
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.83">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 29.14">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 49.67">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.74">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 33.06">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.62">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.70">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.00">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.07">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 32.58">
#             &nbsp;It
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -31.75">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 34.37">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 21.23">
#             &nbsp;not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -12.53">
#             &nbsp;suspicious
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(22, 255, 22);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3.07">
#             &nbsp;if
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 6.97">
#             &nbsp;it
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -6.72">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.79">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 4, 4);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -4.63">
#             &nbsp;legal
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(8, 255, 8);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 4.06">
#             ,
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.45">
#             &nbsp;right
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 10.73">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 21.43">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 47.38">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
# Layer 10
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 100.33">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 107.86">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 145.40">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 180.97">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 86.05">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 146.55">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 116.00">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 133.77">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 103.61">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 43.79">
#             &nbsp;It
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 340.30">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 56.52">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 32.21">
#             &nbsp;not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(198, 255, 198);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 0.45">
#             &nbsp;suspicious
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 59.17">
#             &nbsp;if
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 27.61">
#             &nbsp;it
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 47.70">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 30.87">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.46">
#             &nbsp;legal
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 60.13">
#             ,
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 64.74">
#             &nbsp;right
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 78.63">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 104.12">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 105.43">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: mo
# Layer 15
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 321.84">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 349.77">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 366.11">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 426.55">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 252.68">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 387.71">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 349.52">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 346.98">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 342.04">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 171.20">
#             &nbsp;It
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1500.68">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 185.13">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 160.10">
#             &nbsp;not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 210.33">
#             &nbsp;suspicious
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 184.32">
#             &nbsp;if
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 112.19">
#             &nbsp;it
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 192.66">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 125.83">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 318.69">
#             &nbsp;legal
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 247.99">
#             ,
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 253.95">
#             &nbsp;right
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 247.47">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 383.07">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 336.14">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font
# Layer 20
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 723.70">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 799.82">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 823.42">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 728.99">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 690.82">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 864.90">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 795.86">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 729.04">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 544.97">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 362.65">
#             &nbsp;It
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1414.71">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 591.43">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 590.31">
#             &nbsp;not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 388.33">
#             &nbsp;suspicious
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 382.07">
#             &nbsp;if
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 203.26">
#             &nbsp;it
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 266.85">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 259.27">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 744.46">
#             &nbsp;legal
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 595.72">
#             ,
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 695.84">
#             &nbsp;right
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 638.43">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1028.10">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1132.56">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; fo
# Layer 25
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 109.32">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 526.45">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -163.24">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.30">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 67.34">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 437.16">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 391.80">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 71.10">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -529.48">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -305.22">
#             &nbsp;It
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 64.95">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -345.16">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -331.03">
#             &nbsp;not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -533.44">
#             &nbsp;suspicious
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -621.20">
#             &nbsp;if
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -457.07">
#             &nbsp;it
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 117.24">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -537.86">
#             s
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -378.05">
#             &nbsp;legal
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -597.55">
#             ,
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -333.87">
#             &nbsp;right
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -485.01">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 426.15">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 440.46">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #8

# %%
vis_q(3)
# Out:
# torch.Size([26, 3268, 2304])
# Layer 5
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 21.76">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 25.01">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.20">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 26.85">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 13.76">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.78">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.44">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.11">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 34.06">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.83">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 29.14">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 49.67">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.74">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 33.06">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.62">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.70">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.00">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.07">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 28.42">
#             &nbsp;Not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.39">
#             &nbsp;only
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 16.53">
#             &nbsp;rich
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 27.84">
#             &nbsp;people
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 28.39">
#             &nbsp;can
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 17.46">
#             &nbsp;afford
#         </div>
#
#         <div style="display: inline-block; border: 1px
# Layer 10
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 93.12">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 91.76">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 77.57">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 114.12">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 97.18">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 125.20">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 115.56">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 105.49">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 89.24">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 100.33">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 107.86">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 145.40">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 180.97">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 86.05">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 146.55">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 116.00">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 133.77">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 103.61">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 47.80">
#             &nbsp;Not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 45.32">
#             &nbsp;only
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 89.50">
#             &nbsp;rich
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 121.76">
#             &nbsp;people
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 127.13">
#             &nbsp;can
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 88.68">
#             &nbsp;afford
#         </div>
#
#         <div style="display: inline-block
# Layer 15
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 178.65">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 197.18">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 223.17">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 271.58">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 336.74">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 327.49">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 334.86">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 249.87">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 346.44">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 321.84">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 349.77">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 366.11">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 426.55">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 252.68">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 387.71">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 349.52">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 346.98">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 342.04">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 157.70">
#             &nbsp;Not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 125.37">
#             &nbsp;only
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 256.67">
#             &nbsp;rich
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 327.42">
#             &nbsp;people
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 320.41">
#             &nbsp;can
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 320.98">
#             &nbsp;afford
#         </div>
#
#         <div style="display: in
# Layer 20
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 610.52">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 663.53">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 621.47">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 559.19">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 673.24">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 770.64">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 677.14">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 707.39">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 770.18">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 723.70">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 799.82">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 823.42">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 728.99">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 690.82">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 864.90">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 795.86">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 729.04">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 544.97">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 514.15">
#             &nbsp;Not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 424.40">
#             &nbsp;only
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 895.13">
#             &nbsp;rich
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 876.42">
#             &nbsp;people
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 772.43">
#             &nbsp;can
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 703.99">
#             &nbsp;afford
#         </div>
#
#         <div style="display: in
# Layer 25
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 487.99">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 199.94">
#             ###
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 433.04">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 139.56">
#             Q
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -61.17">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -196.37">
#             &nbsp;Which
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -76.13">
#             &nbsp;statement
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -227.89">
#             &nbsp;is
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -46.41">
#             &nbsp;sarcastic
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 109.32">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 526.45">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -163.24">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.30">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 67.34">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 437.16">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 391.80">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 71.10">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -529.48">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -188.70">
#             &nbsp;Not
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -589.81">
#             &nbsp;only
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -364.49">
#             &nbsp;rich
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -289.29">
#             &nbsp;people
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -300.38">
#             &nbsp;can
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -376.20">
#             &nbsp;afford
#         </div>
#
#         <div style="disp

# %%
vis_q(5, layers=list(range(model.config.num_hidden_layers)))
# Out:
# torch.Size([26, 3290, 2304])
# Layer 0
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.22">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 6.61">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.89">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 35, 35);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -2.59">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 12.56">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 12.54">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 21.73">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 114, 114);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -1.24">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.85">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.45">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(2, 255, 2);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 5.46">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 15.53">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(26, 255, 26);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2.89">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -9.44">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 190, 190);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -0.52">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 15.96">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(5, 255, 5);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 4.52">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.16">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 6.45">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(83, 255, 83);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1.62">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -13.85">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(50, 255, 50);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2.21">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 6.29">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.78">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888
# Layer 1
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 22.35">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 19.36">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.57">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.93">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 25.00">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 22.04">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 36.05">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 18.50">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 24.16">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 18.31">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 13.63">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 18.43">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 10.87">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 9, 9);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -3.94">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.96">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 16.43">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.68">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 17.86">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 10.22">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 12.61">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -7.44">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 8.75">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 19.03">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 19.22">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-fa
# Layer 2
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.37">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 13.04">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 30.33">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(13, 255, 13);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3.63">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 26.64">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 20.05">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.29">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 24.34">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 18.01">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.32">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.17">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.72">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 144, 144);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -0.93">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -15.00">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(14, 255, 14);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3.54">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 17.87">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.86">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 6.51">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(8, 255, 8);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 4.11">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 8.57">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -16.02">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.19">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 9.59">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 10.11">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; fo
# Layer 3
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 30.03">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 19.03">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 33.73">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(1, 255, 1);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 6.18">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 28.85">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 21.11">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.57">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 32.77">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 26.88">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.34">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 10.14">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.58">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(218, 255, 218);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 0.29">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -11.88">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.89">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 29.90">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 28.88">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 13.08">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 20.42">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.61">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -7.69">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 16.41">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.59">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.27">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; fo
# Layer 4
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 30.77">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 23.72">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 37.74">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 26.88">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 30.04">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 22.81">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 37.56">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 36.31">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 18.72">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 12.83">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(133, 255, 133);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1.04">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(8, 255, 8);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 4.13">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -16.20">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -39.30">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -11.02">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 19.37">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.17">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(2, 255, 2);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 5.36">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 7.59">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 27.30">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -13.22">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(216, 255, 216);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 0.30">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(90, 255, 90);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1.53">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 11.28">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #8
# Layer 5
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.83">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 29.14">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 49.67">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 39.74">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 33.06">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 31.62">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.70">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 54.00">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 35.07">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 22.10">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(12, 255, 12);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3.65">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -48.18">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -12.11">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -42.14">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -14.66">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 12.05">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 12.88">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 20, 20);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -3.16">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 132, 132);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -1.05">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 18.65">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -13.90">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -11.69">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 1, 1);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -6.01">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 14.80">
#
#
# ...
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1734.87">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3571.67">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1318.04">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2121.95">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2208.82">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3413.69">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3055.43">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2207.46">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1218.67">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1138.63">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1424.57">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 170.21">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1182.02">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 900.80">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1161.72">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1451.35">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2000.75">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1782.13">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2581.85">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3263.30">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 2377.19">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1305.17">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 1112.88">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 3557.99">
#
#
#         </div>
#
#         <div style="displ
# Layer 25
#     <div style="line-height: 1.5;">
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 109.32">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 526.45">
#
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -163.24">
#             Answer
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 40.30">
#             &nbsp;choices
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 67.34">
#             :
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 437.16">
#
#
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 391.80">
#             (
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 71.10">
#             A
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -529.48">
#             )
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -294.33">
#             &nbsp;You
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 29.71">
#             &nbsp;didn
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 107.99">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -279.45">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -563.42">
#             &nbsp;realize
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -486.48">
#             &nbsp;that
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -45.36">
#             &nbsp;bikes
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 106.81">
#             &nbsp;aren
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 137.31">
#             '
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -230.72">
#             t
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -160.26">
#             &nbsp;a
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -286.17">
#             &nbsp;stationary
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -426.77">
#             &nbsp;object
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(255, 0, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: -499.23">
#             ?
#         </div>
#
#         <div style="display: inline-block; border: 1px solid #888; font-family: monospace;
#                     font-size: 14px; color: black; background-color: rgb(0, 255, 0);
#                     margin: 1px 0px 1px 1px; padding: 0px 1px 1px 1px;"
#              title="Value: 421.86">
#
#
#         </div>
#
#         <div style="display: inline-bloc
